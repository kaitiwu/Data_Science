# %% [markdown]
# # Selecting Rows and Columns in pandas

# %% [markdown]
# ### 1. Reading Data
# We first import `pandas` and load a table into a DataFrame.

# %%
pip install SQLAlchemy
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 3.1 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
pop = pd.read_csv('population.csv', index_col=0)

# %%
pop
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
# American Samoa            8170.0     8156.0     8142.0     8128.0     8114.0
# Andorra                   2654.0     2654.0     2700.0     2835.0     3026.0
# ...                          ...        ...        ...        ...        ...
# Virgin Islands (U.S.)    40000.0    40000.0    40000.0    40000.0    40000.0
# Yemen                  2593000.0  2593000.0  2605438.0  2640779.0  2689275.0
# Zambia                  747000.0   747000.0   747000.0   747000.0   747000.0
# Zimbabwe               1085814.0  1085814.0  1106634.0  1167259.0  1253642.0
# South Sudan            1027378.0  1041076.0  1063732.0  1103246.0  1153401.0
#
# ...

# %% [markdown]
# ### 2. Attributes and Methods
#
# `.shape` is an *attribute*. It can be used with any dataset using a dot. It shows the number of rows and columns in a DataFrame as a Python *tuple*:

# %%
df.shape
# Out:
# (275, 81)

# %% [markdown]
# `.head()` is a *method*. It can be called on any DataFrame object by the dot, followed by parentheses.
# It returns the first N rows of the DataFrame.

# %%
df.head(3)
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
#
#                             1850       1860       1870       1880       1890  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
#
#                        ...        2006        2007        2008        2009  \
# Total population       ...
# Abkhazia               ...         NaN         NaN         NaN         NaN
# Afghanistan            ...  25183615.0  25877544.0  26528741.0  27207291.0
# ...

# %% [markdown]
# ### 3. Selecting Rows and Columns

# %%
### 3. Selecting Rows and Columns
#Match the Python commands with the descriptions below.

#remove rows with missing values
pop.dropna()
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
# American Samoa            8170.0     8156.0     8142.0     8128.0     8114.0
# Andorra                   2654.0     2654.0     2700.0     2835.0     3026.0
# ...                          ...        ...        ...        ...        ...
# Virgin Islands (U.S.)    40000.0    40000.0    40000.0    40000.0    40000.0
# Yemen                  2593000.0  2593000.0  2605438.0  2640779.0  2689275.0
# Zambia                  747000.0   747000.0   747000.0   747000.0   747000.0
# Zimbabwe               1085814.0  1085814.0  1106634.0  1167259.0  1253642.0
# South Sudan            1027378.0  1041076.0  1063732.0  1103246.0  1153401.0
#
# ...

# %%
#select a single row
display(pop.iloc[:1])
# Out:
#                        1800       1810       1820       1830       1840  \
# Total population
# Afghanistan       3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
#
#                        1850       1860       1870       1880       1890  ...  \
# Total population                                                         ...
# Afghanistan       3810047.0  3973968.0  4169690.0  4419695.0  4710171.0  ...
#
#                         2006        2007        2008        2009        2010  \
# Total population
# Afghanistan       25183615.0  25877544.0  26528741.0  27207291.0  27962207.0
#
#                         2011        2012        2013        2014        2015
# Total population
# Afghanistan       28809167.0  29726803.0  30682500.0  31627506.0  32526562.0
#
# [1 rows x 81 columns]

# %%
#inspect column labels
pop.columns
# Out:
# Index(['1800', '1810', '1820', '1830', '1840', '1850', '1860', '1870', '1880',
#        '1890', '1900', '1910', '1920', '1930', '1940', '1950', '1951', '1952',
#        '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')

# %%
#select multiple columns
pop.iloc[:, 0:6]
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
# American Samoa            8170.0     8156.0     8142.0     8128.0     8114.0
# Andorra                   2654.0     2654.0     2700.0     2835.0     3026.0
# ...                          ...        ...        ...        ...        ...
# Virgin Islands (U.S.)    40000.0    40000.0    40000.0    40000.0    40000.0
# Yemen                  2593000.0  2593000.0  2605438.0  2640779.0  2689275.0
# Zambia                  747000.0   747000.0   747000.0   747000.0   747000.0
# Zimbabwe               1085814.0  1085814.0  1106634.0  1167259.0  1253642.0
# South Sudan            1027378.0  1041076.0  1063732.0  1103246.0  1153401.0
#
# ...

# %%
#select rows by position

# %%
pop.iloc[3:4]
# Out:
#                     1800    1810    1820    1830    1840    1850    1860  \
# Total population
# American Samoa    8170.0  8156.0  8142.0  8128.0  8114.0  7958.0  7564.0
#
#                     1870    1880    1890  ...     2006     2007     2008  \
# Total population                          ...
# American Samoa    7057.0  6582.0  6139.0  ...  58648.0  57904.0  57031.0
#
#                      2009     2010     2011     2012     2013     2014  \
# Total population
# American Samoa    56226.0  55636.0  55316.0  55227.0  55302.0  55434.0
#
#                      2015
# Total population
# American Samoa    55538.0
#
# [1 rows x 81 columns]

# %%
#select rows that match a condition
pop.loc[['Japan', 'China', 'Brazil']]
# Out:
#                          1800         1810         1820         1830  \
# Total population
# Japan              30294378.0   30645903.0   30993147.0   31330455.0
# China             321675013.0  350542958.0  380055273.0  402373519.0
# Brazil              3639636.0    4058652.0    4582325.0    5301068.0
#
#                          1840         1850         1860         1870  \
# Total population
# Japan              31663783.0   32223184.0   33176900.0   34638021.0
# China             411213424.0  402711280.0  380047548.0  363661158.0
# Brazil              6206694.0    7254194.0    8466005.0    9964419.0
#
#                          1880         1890  ...          2006          2007  \
# Total population                            ...
# Japan              36826469.0   39878734.0  ...  1.271366e+08  1.272500e+08
# China             365544192.0  377135349.0  ...  1.312601e+09  1.319625e+09
# Brazil             11893392.0   14410738.0  ...  1.906982e+08  1.927845e+08
#
# ...

# %%
#select multiple rows
pop.loc[['Japan', 'China', 'Brazil']]
# Out:
#                          1800         1810         1820         1830  \
# Total population
# Japan              30294378.0   30645903.0   30993147.0   31330455.0
# China             321675013.0  350542958.0  380055273.0  402373519.0
# Brazil              3639636.0    4058652.0    4582325.0    5301068.0
#
#                          1840         1850         1860         1870  \
# Total population
# Japan              31663783.0   32223184.0   33176900.0   34638021.0
# China             411213424.0  402711280.0  380047548.0  363661158.0
# Brazil              6206694.0    7254194.0    8466005.0    9964419.0
#
#                          1880         1890  ...          2006          2007  \
# Total population                            ...
# Japan              36826469.0   39878734.0  ...  1.271366e+08  1.272500e+08
# China             365544192.0  377135349.0  ...  1.312601e+09  1.319625e+09
# Brazil             11893392.0   14410738.0  ...  1.906982e+08  1.927845e+08
#
# ...

# %%
pop.loc['Brazil', '2000']
# Out:
# 175786441.0

# %%
#Select a single column
pop.loc[:,'2000']
# Out:
# Total population
# Afghanistan              19701940.0
# Albania                   3121965.0
# Algeria                  31183658.0
# American Samoa              57522.0
# Andorra                     65399.0
#                             ...
# Virgin Islands (U.S.)      108511.0
# Yemen                    17795219.0
# Zambia                   10585220.0
# Zimbabwe                 12499981.0
# South Sudan               6692999.0
# Name: 2000, Length: 229, dtype: float64

# %%
#select values in a given range
pop.loc[['Japan', 'China', 'Brazil']]
# Out:
#                          1800         1810         1820         1830  \
# Total population
# Japan              30294378.0   30645903.0   30993147.0   31330455.0
# China             321675013.0  350542958.0  380055273.0  402373519.0
# Brazil              3639636.0    4058652.0    4582325.0    5301068.0
#
#                          1840         1850         1860         1870  \
# Total population
# Japan              31663783.0   32223184.0   33176900.0   34638021.0
# China             411213424.0  402711280.0  380047548.0  363661158.0
# Brazil              6206694.0    7254194.0    8466005.0    9964419.0
#
#                          1880         1890  ...          2006          2007  \
# Total population                            ...
# Japan              36826469.0   39878734.0  ...  1.271366e+08  1.272500e+08
# China             365544192.0  377135349.0  ...  1.312601e+09  1.319625e+09
# Brazil             11893392.0   14410738.0  ...  1.906982e+08  1.927845e+08
#
# ...

# %%
#select rows and columns by position
pop.iloc[4:9]
# Out:
#                           1800       1810       1820       1830       1840  \
# Total population
# Andorra                 2654.0     2654.0     2700.0     2835.0     3026.0
# Angola               1567028.0  1567028.0  1597530.0  1686390.0  1813100.0
# Anguilla                2025.0     2025.0     2064.0     2177.0     2338.0
# Antigua and Barbuda    37000.0    37000.0    37000.0    37000.0    37000.0
# Argentina             534000.0   534000.0   570719.0   686703.0   873747.0
#
#                           1850       1860       1870       1880       1890  \
# Total population
# Andorra                 3230.0     3436.0     3654.0     3885.0     4131.0
# Angola               1949329.0  2110747.0  2285417.0  2473597.0  2677047.0
# Anguilla                2511.0     2693.0     2888.0     3097.0     3320.0
# Antigua and Barbuda    37000.0    36532.0    35546.0    35222.0    36286.0
# Argentina            1113189.0  1421333.0  1856886.0  2493156.0  3402273.0
#
# ...

# %%
#inspect row labels
for row in pop.index:
    print(row, end = " ")
# Out:
# Afghanistan Albania Algeria American Samoa Andorra Angola Anguilla Antigua and Barbuda Argentina Armenia Aruba Australia Austria Azerbaijan Bahamas Bahrain Bangladesh Barbados Belarus Belgium Belize Benin Bermuda Bhutan Bolivia Bosnia and Herzegovina Botswana Brazil British Virgin Islands Brunei Bulgaria Burkina Faso Burundi Cambodia Cameroon Canada Cape Verde Cayman Islands Central African Republic Chad Channel Islands Chile China Colombia Comoros Congo, Dem. Rep. Congo, Rep. Cook Is Costa Rica Cote d'Ivoire Croatia Cuba Cyprus Czech Republic Denmark Djibouti Dominica Dominican Republic Ecuador Egypt El Salvador Equatorial Guinea Eritrea Estonia Ethiopia Faeroe Islands Falkland Is (Malvinas) Fiji Finland France French Guiana French Polynesia Gabon Gambia Georgia Germany Ghana Gibraltar Greece Greenland Grenada Guadeloupe Guam Guatemala Guinea Guinea-Bissau Guyana Haiti Holy See Honduras Hong Kong, China Hungary Iceland India Indonesia Iran Iraq Ireland Isle of Man Israel Italy Jamai
# ...

# %%
#select rows and columns @A@? what do you want? what row and what columns?

# %% [markdown]
# Create new Markdown cells in the notebook to have a heading for each command.

# %%
df.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'British Indian Ocean Territory', 'Clipperton',
#        'French Southern and Antarctic Lands', 'Gaza Strip',
#        'Heard and McDonald Islands', 'Northern Marianas',
#        'South Georgia and the South Sandwich Islands',
#        'US Minor Outlying Islands', 'Virgin Islands', 'West Bank'],
#       dtype='object', name='Total population', length=275)

# %%
df.columns
# Out:
# Index(['1800', '1810', '1820', '1830', '1840', '1850', '1860', '1870', '1880',
#        '1890', '1900', '1910', '1920', '1930', '1940', '1950', '1951', '1952',
#        '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')

# %%
df['2015']
# Out:
# Total population
# Abkhazia                                               NaN
# Afghanistan                                     32526562.0
# Akrotiri and Dhekelia                                  NaN
# Albania                                          2896679.0
# Algeria                                         39666519.0
#                                                    ...
# Northern Marianas                                      NaN
# South Georgia and the South Sandwich Islands           NaN
# US Minor Outlying Islands                              NaN
# Virgin Islands                                         NaN
# West Bank                                              NaN
# Name: 2015, Length: 275, dtype: float64

# %%
df[['1900', '1950', '2000']]
# Out:
#                                                    1900       1950        2000
# Total population
# Abkhazia                                            NaN        NaN         NaN
# Afghanistan                                   5021241.0  7752118.0  19701940.0
# Akrotiri and Dhekelia                               NaN    10661.0     15157.0
# Albania                                        819950.0  1263171.0   3121965.0
# Algeria                                       4946166.0  8872247.0  31183658.0
# ...                                                 ...        ...         ...
# Northern Marianas                                   NaN        NaN         NaN
# South Georgia and the South Sandwich Islands        NaN        NaN         NaN
# US Minor Outlying Islands                           NaN        NaN         NaN
# Virgin Islands                                      NaN        NaN         NaN
# West Bank                                           NaN        NaN         NaN
#
# ...

# %%
df.loc['Estonia']
# Out:
# 1800     334136.0
# 1810     334136.0
# 1820     342427.0
# 1830     366799.0
# 1840     402035.0
#           ...
# 2011    1328068.0
# 2012    1324040.0
# 2013    1320050.0
# 2014    1316203.0
# 2015    1312558.0
# Name: Estonia, Length: 81, dtype: float64

# %%
df.loc[['Japan', 'China', 'Brazil']]
# Out:
#                          1800         1810         1820         1830  \
# Total population
# Japan              30294378.0   30645903.0   30993147.0   31330455.0
# China             321675013.0  350542958.0  380055273.0  402373519.0
# Brazil              3639636.0    4058652.0    4582325.0    5301068.0
#
#                          1840         1850         1860         1870  \
# Total population
# Japan              31663783.0   32223184.0   33176900.0   34638021.0
# China             411213424.0  402711280.0  380047548.0  363661158.0
# Brazil              6206694.0    7254194.0    8466005.0    9964419.0
#
#                          1880         1890  ...          2006          2007  \
# Total population                            ...
# Japan              36826469.0   39878734.0  ...  1.271366e+08  1.272500e+08
# China             365544192.0  377135349.0  ...  1.312601e+09  1.319625e+09
# Brazil             11893392.0   14410738.0  ...  1.906982e+08  1.927845e+08
#
# ...

# %%
df.loc['Croatia', '2000']
# Out:
# 4428069.0

# %%
df.iloc[10:15]
# Out:
#                        1800       1810       1820       1830       1840  \
# Total population
# Argentina          534000.0   534000.0   570719.0   686703.0   873747.0
# Armenia            413326.0   413326.0   423527.0   453507.0   496835.0
# Aruba               19286.0    19286.0    19555.0    20332.0    21423.0
# Australia          351014.0   342440.0   334002.0   348143.0   434095.0
# Austria           3205587.0  3286650.0  3391206.0  3538286.0  3728381.0
#
#                        1850       1860       1870       1880       1890  ...  \
# Total population                                                         ...
# Argentina         1113189.0  1421333.0  1856886.0  2493156.0  3402273.0  ...
# Armenia            544302.0   595928.0   652450.0   713957.0   781218.0  ...
# Aruba               22574.0    23786.0    25063.0    26404.0    27817.0  ...
# Australia          742619.0  1256048.0  1724213.0  2253007.0  3088808.0  ...
# ...

# %%
df.iloc[10:15, 75:]
# Out:
#                         2010        2011        2012        2013        2014  \
# Total population
# Argentina         41222875.0  41655616.0  42095224.0  42538304.0  42980026.0
# Armenia            2963496.0   2967984.0   2978339.0   2992192.0   3006154.0
# Aruba               101597.0    101936.0    102393.0    102921.0    103441.0
# Australia         22162863.0  22542371.0  22911375.0  23270465.0  23622353.0
# Austria            8391986.0   8423559.0   8455477.0   8486962.0   8516916.0
#
#                         2015
# Total population
# Argentina         43416755.0
# Armenia            3017712.0
# Aruba               103889.0
# Australia         23968973.0
# Austria            8544586.0

# %%
df.loc[df['2000'] > 200_000_000]
# Out:
#                          1800         1810         1820         1830  \
# Total population
# China             321675013.0  350542958.0  380055273.0  402373519.0
# India             168574895.0  171940819.0  176225709.0  182214537.0
# Indonesia          16108545.0   16537268.0   17236636.0   18460171.0
# United States       6801854.0    8294928.0   10361646.0   13480460.0
# USSR                      NaN          NaN          NaN          NaN
#
#                          1840         1850         1860         1870  \
# Total population
# China             411213424.0  402711280.0  380047548.0  363661158.0
# India             189298397.0  196657653.0  204966302.0  213725049.0
# Indonesia          20052305.0   21979198.0   24209376.0   27062539.0
# United States      17942443.0   24136293.0   31936643.0   40821569.0
# USSR                      NaN          NaN          NaN          NaN
#
#                          1880         1890  ...          2006          2007  \
# ...

# %%
df[df['2000'].between(500_000, 1_000_000)]
# Out:
#                        1800      1810      1820      1830      1840      1850  \
# Total population
# Bahrain             64474.0   64474.0   64474.0   64474.0   64474.0   64474.0
# Bhutan              89989.0   89989.0   91144.0   94472.0   99137.0  104032.0
# Comoros             56346.0   56346.0   57537.0   61016.0   65999.0   71389.0
# Cyprus             184392.0  184590.0  184788.0  184986.0  185184.0  185383.0
# Djibouti            22848.0   22848.0   23320.0   24698.0   26670.0   28798.0
# Equatorial Guinea   80377.0   80377.0   81084.0   83105.0   85909.0   88807.0
# Fiji               130533.0  132682.0  134860.0  137074.0  138446.0  137063.0
# Guyana             166034.0  166034.0  169103.0  178030.0  190726.0  204328.0
# Montenegro         126582.0  126582.0  129599.0  138454.0  151224.0  165172.0
# Qatar               14092.0   14092.0   14092.0   14092.0   14092.0   14092.0
# Reunion             92744.0   92744.0   94632.0  100142.0  108016.0  116510.0
# ...

# %%
df.dropna()
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
# American Samoa            8170.0     8156.0     8142.0     8128.0     8114.0
# Andorra                   2654.0     2654.0     2700.0     2835.0     3026.0
# ...                          ...        ...        ...        ...        ...
# Virgin Islands (U.S.)    40000.0    40000.0    40000.0    40000.0    40000.0
# Yemen                  2593000.0  2593000.0  2605438.0  2640779.0  2689275.0
# Zambia                  747000.0   747000.0   747000.0   747000.0   747000.0
# Zimbabwe               1085814.0  1085814.0  1106634.0  1167259.0  1253642.0
# South Sudan            1027378.0  1041076.0  1063732.0  1103246.0  1153401.0
#
# ...

# %% [markdown]
# ## License
# (c) 2017 Kristian Rother.
# Distributed under the conditions of the MIT License.

# %%
import pandas as pd

data = [[82_000_000, 1.9, "Europe"],
        [ 5_500_000, 1.8, "Europe"]]

df = pd.DataFrame(data,
                  columns=['population', 'fertility', 'continent'],
                  index=['Germany', 'Denmark'])

# %%
data = {'spices': ['parsley', 'sage', 'rosemary', 'thyme'],
        'value': [1.2, 3.4, np.nan, 5.6],
        'good_for_spaghetti': [False, False, True, True]}

labels = ['a', 'b', 'c', 'd']
df=pd.DataFrame(data,index=labels)

# %%
import numpy as np

# %%
df = pd.read_csv("large_countries_2015.csv", index_col=0)

# %% [markdown]
# Fix 5 bugs

# %%
import pandas

spices = ['One-Hot Chili Peppers',
          'Bayesian Basil',
          'Tensor Thyme'
          'Linear Lavender',
          'Artificial Neural Nutmeg',
          'Polynomial Peppermint',
          'Sigmoid Saffron'
          ]
participants = [2, 6, 9, 9, 9, 8]

df = pd.DataFrame({'name': spices,
                   'participants': participants
                   })

print(df.sort_values(by=['participants'], ascending=False))

print("\ntotal participants:", df['participants'].sum())
# Out:
#                           name  participants
# 2  Tensor ThymeLinear Lavender             9
# 3     Artificial Neural Nutmeg             9
# 4        Polynomial Peppermint             9
# 5              Sigmoid Saffron             8
# 1               Bayesian Basil             6
# 0        One-Hot Chili Peppers             2
#
# total participants: 43

# %% [markdown]
# Solve with oneliner

# %%
import pandas as pd

# 1. read the file into a DataFrame
df = pd.read_csv("continents.csv", index_col=None, sep=";")

# 2. display the number of rows and columns
...
df.shape
# 3. display the first 5 countries in the alphabet
df.head()

# 4. which continent has the most countries?
df.continent.value_counts() #Africa has the most countries

# 5. find out on which continent Cyprus is
df.loc[df['country'] == "Cyprus"]

# 6. define a DataFrame with all African countries
africa = africa = df.loc[df["continent"]=="Africa"]
africa

# 7. define a DataFrame with countries 80 through 100
subset = df.iloc[81:101]

# 8. select every second country
...

df.loc[df['country'] == "Cyprus"]
# Out:
# Ellipsis

# %%
df.iloc[:,:4]
# Out:
#          continent    country
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
# [194 rows x 2 columns]

# %% [markdown]
# ## Draw a histogram

# %%
pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 249 kB 2.5 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
life = pd.read_excel('gapminder_lifeexpectancy.xlsx', index_col=0)
fert = pd.read_csv('gapminder_total_fertility.csv', index_col=0)

# %%
life.dropna(inplace=True)
life
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# Angola                 26.98  26.98  26.98  26.98  26.98  26.98  26.98  26.98
# Antigua and Barbuda    33.54  33.54  33.54  33.54  33.54  33.54  33.54  33.54
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# Virgin Islands (U.S.)  33.40  33.40  33.40  33.40  33.40  33.40  33.40  33.40
# Yemen                  23.39  23.39  23.39  23.39  23.39  23.39  23.39  23.39
# Zambia                 32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe               33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# South Sudan            26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %%
fert.dropna(inplace=True)
fert
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# Angola                 6.93  6.93  6.93  6.93  6.93  6.93  6.93  6.94  6.94
# Antigua and Barbuda    5.00  5.00  4.99  4.99  4.99  4.98  4.98  4.97  4.97
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Vietnam                4.70  4.70  4.70  4.70  4.70  4.70  4.70  4.70  4.70
# Virgin Islands (U.S.)  5.55  5.55  5.55  5.55  5.55  5.55  5.55  5.55  5.55
# Yemen                  6.88  6.88  6.88  6.88  6.88  6.88  6.88  6.88  6.88
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
#
# ...

# %%
# draw histogram for year 2015

# %%
life.hist(1986, facecolor='#ff0109',alpha=0.09,
histtype='bar')
plt.title('Life expectancy glob in 1986')
plt.xlabel('Age')
plt.ylabel('Number of Countries')
# Out:
# Text(0, 0.5, 'Number of Countries')

# %%
plt.savefig('histo.png')

# %% [markdown]
# Data round trip csv --> excel --> sql

# %%
life.to_excel (r'life_as_excel.xlsx', index = None, header=True)
sqlb = pd.read_excel(r"life_as_excel.xlsx")
engine = create_engine('sqlite://', echo=False)
sqlb.to_sql("life_as_sql.db", con=engine)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [263], line 5
#       3 engine = create_engine('sqlite://', echo=False)
#       4 sqlb.to_sql("life_as_sql.db", con=engine)
# ----> 5 cnx = sqlalchemy.connect('sqlb.db')
#
# AttributeError: module 'sqlalchemy' has no attribute 'connect'

# %%
sqlb
# Out:
#       1800   1801   1802   1803   1804   1805   1806   1807   1808   1809  \
# 0    28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14  28.13  28.12
# 1    35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 2    28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# 3    26.98  26.98  26.98  26.98  26.98  26.98  26.98  26.98  26.98  26.98
# 4    33.54  33.54  33.54  33.54  33.54  33.54  33.54  33.54  33.54  33.54
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 196  33.40  33.40  33.40  33.40  33.40  33.40  33.40  33.40  33.40  33.40
# 197  23.39  23.39  23.39  23.39  23.39  23.39  23.39  23.39  23.39  23.39
# 198  32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# 199  33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# 200  26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
#      ...   2007   2008   2009   2010   2011   2012   2013   2014  2015   2016
# ...
